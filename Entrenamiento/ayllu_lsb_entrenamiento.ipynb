# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
import tensorflow as tf
from mediapipe.tasks import python
from mediapipe.tasks.python import vision
# Out:
# 2025-07-04 20:43:10.218700: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-04 20:43:10.469848: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751676190.570759    4331 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751676190.600457    4331 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1751676190.827514    4331 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1751676190.827535    4331 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1751676190.827537    4331 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1751676190.827538    4331 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-07-04 20:43:10.849683: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/brandon/anaconda3/envs/ayllu_lsb/lib/python3.11/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_styled_landmarks(image, results):
    mp_drawing = mp.solutions.drawing_utils
    mp_holistic = mp.solutions.holistic
    mp_face_mesh = mp.solutions.face_mesh # Import face_mesh module

    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_face_mesh.FACEMESH_TESSELATION,
                              mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                              mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                              )
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                              mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                              mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                              )
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                              mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                              mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                              )
    # Draw right hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                              mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                              mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                              )

# %%
cap = cv2.VideoCapture(2)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1751674975.458990    7110 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1751674975.484486    7110 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1751674975.487896    7110 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1751674975.487977    7109 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1751674975.489157    7113 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1751674975.496502    7113 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1751674975.509333    7110 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1751674975.509367    7107 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1751674976.271464    7107 landmark_projection_calculator.cc:186] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 pose = []
# ----> 2 for res in results.pose_landmarks.landmark:
#       3     test = np.array([res.x, res.y, res.z, res.visibility])
#       4     pose.append(test)
#
# NameError: name 'results' is not defined

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
DATA_PATH = os.path.join('MP_Data') 

actions = np.array(['hola','gracias'])

no_sequences = 30

sequence_length = 30

# %%
for action in actions: 
    for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %%
cap = cv2.VideoCapture(2)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)
#                 print(results)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(2000)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()
# Out:
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# W0000 00:00:1751675171.180490    7251 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1751675171.203583    7251 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1751675171.205343    7248 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1751675171.206800    7255 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1751675171.207768    7251 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1751675171.215601    7252 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1751675171.216446    7248 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1751675171.222084    7255 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.

# %%
cap.release()
cv2.destroyAllWindows()

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'hola': 0, 'gracias': 1}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (60, 30, 1662)

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (60, 30, 1662)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
y_test.shape
# Out:
# (3, 2)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
from tensorflow.keras import Input
model = Sequential()
model.add(Input(shape=(30,1662)))
model.add(LSTM(64, return_sequences=True, activation='relu'))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))
# Out:
# I0000 00:00:1751676319.238854    4331 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1730 MB memory:  -> device: 0, name: NVIDIA GeForce MX330, pci bus id: 0000:02:00.0, compute capability: 6.1

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=1000, callbacks=[tb_callback])
# Out:
# Epoch 1/1000
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1751676327.021084    4918 service.cc:152] XLA service 0x157579b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1751676327.021100    4918 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce MX330, Compute Capability 6.1
# 2025-07-04 20:45:27.105274: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1751676327.613893    4918 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 1/2 ━━━━━━━━━━━━━━━━━━━━
1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 332/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 333/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 334/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 335/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 336/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 337/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 338/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 339/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 340/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 341/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 342/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 343/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 344/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 345/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 346/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 347/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 348/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 349/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 350/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 351/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 352/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 353/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 354/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 355/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 356/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 357/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 358/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 359/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 360/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 361/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 362/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 363/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 364/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 365/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 366/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 367/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 368/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 369/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 370/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 371/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 372/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 373/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 374/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 375/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 376/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 377/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 378/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 379/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 380/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 381/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 382/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 383/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 384/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 385/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 386/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 387/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 388/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 389/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 390/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 391/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 392/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 393/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 394/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 395/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 396/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 397/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 398/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 399/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 400/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 401/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 402/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 403/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 404/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 405/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 406/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 407/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 408/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 409/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 410/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 411/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 412/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 413/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 414/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 415/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 416/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 417/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 418/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 419/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 420/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 421/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 422/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 423/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 424/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 425/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 426/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 427/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 428/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 429/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 430/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 431/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 432/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 433/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 434/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 435/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 436/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 437/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 438/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 439/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 440/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 441/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 442/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 443/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 444/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 445/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 446/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 447/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 448/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 449/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 450/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 451/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 452/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 453/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 454/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 455/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 456/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 457/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 458/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 459/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 460/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 461/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 462/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 463/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 464/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 465/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 466/1000
# ...
# Epoch 846/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 847/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 848/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 849/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 850/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 851/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 852/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 853/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 854/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 855/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 856/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 857/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 858/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 859/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 860/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 861/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 862/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 863/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 864/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 865/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 866/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 867/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 868/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 869/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 870/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 871/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 872/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 873/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 874/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 875/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 876/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 877/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 878/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 879/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 880/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 881/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 882/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 883/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 884/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 885/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 886/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 887/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 888/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 889/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 890/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 891/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 892/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 893/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 894/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 895/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 896/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 897/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 898/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 899/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 900/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 901/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 902/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 903/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 904/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 905/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 906/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 907/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 908/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 909/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 910/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 911/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 912/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 913/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 914/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 915/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 916/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 917/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 918/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 919/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 920/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 921/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 922/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 923/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 924/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 925/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 926/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 927/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 928/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 929/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 930/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 931/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 932/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 933/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 934/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 935/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 936/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 937/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 938/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 939/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 940/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 941/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 942/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 943/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 944/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 945/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 946/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 947/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 948/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 949/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 950/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 951/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 952/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 953/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 954/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 955/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 956/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 957/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 958/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 959/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 960/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 961/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 962/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 963/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 964/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 965/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 966/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 967/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 968/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 969/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 970/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 971/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 972/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 973/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 974/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 975/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 976/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 977/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 978/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 979/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 980/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 981/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 982/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 983/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 984/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 985/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 986/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 987/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 988/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 989/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 990/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 991/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 992/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 993/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 994/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 995/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 996/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 997/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 998/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 999/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 1000/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0000e+00

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 30, 64)         │       442,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 30, 128)        │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,789,928 (6.83 MB)
#  Trainable params: 596,642 (2.28 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,193,286 (4.55 MB)

# %%
model.save('action.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model.load_weights('action.h5')

# %%
import tensorflow as tf

# Cargar el modelo
model = tf.keras.models.load_model('action.h5')

# Convertirlo a TFLite con soporte para ops de TF
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.target_spec.supported_ops = [
    tf.lite.OpsSet.TFLITE_BUILTINS,     # Operaciones estándar de TFLite
    tf.lite.OpsSet.SELECT_TF_OPS        # Operaciones adicionales de TensorFlow necesarias para LSTM
]
converter._experimental_lower_tensor_list_ops = False

# Convertir el modelo
tflite_model = converter.convert()

# Guardar el archivo .tflite
with open('pesos_ayllu_lsb.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: /tmp/tmpnus68mk7/assets
# INFO:tensorflow:Assets written to: /tmp/tmpnus68mk7/assets
# Saved artifact at '/tmp/tmpnus68mk7'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 30, 1662), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   129143493601488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   129143493601872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   129143493600528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   129143493601104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   129143493600144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   129143493599760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   129143493603792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   129143493599376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   129143493598992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   129146384285520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   129143493601296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   129143493598800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   129143493604368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   129143493600336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   129143493598416: TensorSpec(shape=(), dtype=tf.resource, name=None)
# W0000 00:00:1751677348.761440    4331 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1751677348.761454    4331 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# 2025-07-04 21:02:28.761581: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpnus68mk7
# 2025-07-04 21:02:28.762411: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2025-07-04 21:02:28.762417: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmpnus68mk7
# 2025-07-04 21:02:28.772296: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2025-07-04 21:02:28.816920: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmpnus68mk7
# 2025-07-04 21:02:28.834001: I tensorflow/cc/saved_model/loader.cc:471] SavedModel load for tags { serve }; Status: success: OK. Took 72421 microseconds.
# 2025-07-04 21:02:29.003590: W tensorflow/compiler/mlir/lite/flatbuffer_export.cc:3993] TFLite interpreter needs to link Flex delegate in order to run the model since it contains the following Select TFop(s):
# TensorListSetItem, FlexTensorListStack
# Details:
# 	tf.TensorListReserve(tensor<2xi32>, tensor<i32>) -> (tensor<!tf_type.variant<tensor<?x128xf32>>>) : {device = ""}
# 	tf.TensorListReserve(tensor<2xi32>, tensor<i32>) -> (tensor<!tf_type.variant<tensor<?x64xf32>>>) : {device = ""}
# 	tf.TensorListSetItem(tensor<!tf_type.variant<tensor<?x128xf32>>>, tensor<i32>, tensor<?x128xf32>) -> (tensor<!tf_type.variant<tensor<?x128xf32>>>) : {device = "", resize_if_index_out_of_bounds = false}
# 	tf.TensorListSetItem(tensor<!tf_type.variant<tensor<?x64xf32>>>, tensor<i32>, tensor<?x64xf32>) -> (tensor<!tf_type.variant<tensor<?x64xf32>>>) : {device = "", resize_if_index_out_of_bounds = false}
# 	tf.TensorListStack(tensor<!tf_type.variant<tensor<?x128xf32>>>, tensor<2xi32>) -> (tensor<30x?x128xf32>) : {device = "", num_elements = 30 : i64}
# 	tf.TensorListStack(tensor<!tf_type.variant<tensor<?x64xf32>>>, tensor<2xi32>) -> (tensor<1x?x64xf32>) : {device = "", num_elements = 1 : i64}
# 	tf.TensorListStack(tensor<!tf_type.variant<tensor<?x64xf32>>>, tensor<2xi32>) -> (tensor<30x?x64xf32>) : {device = "", num_elements = 30 : i64}
# See instructions: https://www.tensorflow.org/lite/guide/ops_select

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
plt.figure(figsize=(18,18))
plt.imshow(prob_viz(res, actions, image, colors))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 plt.figure(figsize=(18,18))
# ----> 2 plt.imshow(prob_viz(res, actions, image, colors))
#
# NameError: name 'image' is not defined

# %%
sequence = []
sentence = []
threshold = 0.8

cap = cv2.VideoCapture(2)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
#         sequence.insert(0,keypoints)
#         sequence = sequence[:30]
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            
            
        #3. Viz logic
            if res[np.argmax(res)] > threshold: 
                if len(sentence) > 0: 
                    if actions[np.argmax(res)] != sentence[-1]:
                        sentence.append(actions[np.argmax(res)])
                else:
                    sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1751676537.417208   25060 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1751676537.440418   25060 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1751676537.443815   25060 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1751676537.443844   25063 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1751676537.444101   25065 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1751676537.451905   25065 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1751676537.459406   25063 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1751676537.459431   25060 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# W0000 00:00:1751676538.044740   25067 landmark_projection_calculator.cc:186] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 686ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# gracias
# ...
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# gracias
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# hola
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# hola
